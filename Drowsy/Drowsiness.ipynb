# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2
import time

# %%
model = YOLO('yolov8n.pt')  # load model
model.train(data='C:\\Users\\chorn\\Documents\\Kuliah-Semester-5\\Deep Learning - I\\Drowsy\\YOLO\\DrowsyV2\\data.yaml', epochs=100)
# Out:
# Ultralytics 8.3.230  Python-3.13.7 torch-2.9.1+cpu CPU (12th Gen Intel Core i5-12450HX)
# ...

# %%
model = YOLO('runs/detect/train27/weights/best.pt')  # jika ingin memakai model yang sudah ditraining

# %%
img = 'https://i.pinimg.com/736x/c8/40/4a/c8404a3376fac98a20099a9d6fb650fe.jpg'

# %%
results = model(img)
# Out:
# Found https://i.pinimg.com/736x/c8/40/4a/c8404a3376fac98a20099a9d6fb650fe.jpg locally at c8404a3376fac98a20099a9d6fb650fe.jpg
# image 1/1 c:\Users\chorn\Documents\Kuliah-Semester-5\Deep Learning - I\Drowsy\YOLO\c8404a3376fac98a20099a9d6fb650fe.jpg: 640x512 1 Drowsy, 52.3ms
# Speed: 3.1ms preprocess, 52.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)

# %%
cam = cv2.VideoCapture(0)
if not cam.isOpened():
    raise Exception("No Camera")

while True:
    ret, frame = cam.read()
    if not ret:
        break

    start = time.time()
    result = model(frame)
    annotated = result[0].plot()

    cv2.imshow("YOLO Detection", annotated)
    print("Waktu:", time.time() - start)

    if cv2.waitKey(1) & 0xFF == ord('e'):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Awake, 1 Drowsy, 55.9ms
# Speed: 2.6ms preprocess, 55.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Waktu: 0.09500932693481445
#
# 0: 384x640 1 Drowsy, 74.7ms
# Speed: 2.4ms preprocess, 74.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Waktu: 0.08607697486877441
#
# 0: 384x640 1 Drowsy, 69.3ms
# Speed: 2.3ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Waktu: 0.07928681373596191
#
# 0: 384x640 1 Drowsy, 105.0ms
# Speed: 1.3ms preprocess, 105.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Waktu: 0.11621570587158203
#
# 0: 384x640 2 Drowsys, 61.2ms
# Speed: 1.6ms preprocess, 61.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Waktu: 0.0751187801361084
#
# 0: 384x640 2 Drowsys, 56.2ms
# Speed: 2.2ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Waktu: 0.06758499145507812
#
# ...
